# %%
import pygame

# %%
pygame.init()  
scr = pygame.display.set_mode((600,500))  
pygame.display.set_caption('Gra - Warcaby')
done = False  
while not done:  
    for event in pygame.event.get():  
        if event.type == pygame.QUIT:  
            done = True  
pygame.display.flip()

# %%
import pygame
pygame.init() 
scr = pygame.display.set_mode((600,500))
print(scr)
x, y = scr.get_size() 
pygame.display.quit() 
print(x, y)

# %%
import pygame 
import sys  
import os

pygame.init()

X = 500
Y = 550
os.environ['SDL_VIDEO_WINDOW_POS'] = "%d,%d" % (X,Y)

s = (800, 1000)

screen = pygame.display.set_mode(s)

# przechowujemy kolory
color_white = (255,255,255) 
color_light = (180,180,180) 
color_dark = (110,110,110) 

#wysokosc i szerokosc ekranu
width = screen.get_width()
height = screen.get_height()  

#definicja czcionki i rozmiar
smallfont = pygame.font.SysFont('Arial',80) 
text1 = smallfont.render('B' , True , color_white) 
text2 = smallfont.render('C' , True , color_white) 


while True:     
    for e in pygame.event.get():      
        if e.type == pygame.QUIT: 
            pygame.quit()      
        if e.type == pygame.MOUSEBUTTONDOWN:  #sprawdza czy mysz jest klikana
            # jesli mysz klikana sprawdzamy cyz jest kliknana na guzik
            if width/2 <= mouse[0] <= width/2+140 and height/2 <= mouse[1] <= height/2+40: 
                pygame.quit() 
                
    #screen.fill((0,0,0)) #wypelnia ekran czarnym kolorem
    
    
    mouse = pygame.mouse.get_pos() 
    
    
    
    #SZACHOWNICA PLANSZA
    
    
    liczba_wierszy = 8
    liczba_kolumn = 8
    buttons = []
    
    for i in range(liczba_wierszy):
        buttons.append([0] * liczba_kolumn)

        
        
    #malujemy 64 guzików: plasza 8x8
    buttons_count = -1
    
    for wiersz in range (1,9):
        buttons_count += 1
        for guzik in range (0,8):
            buttons[buttons_count][guzik]=[100*guzik, 100*wiersz, 100, 100]
            
            #ustawiamy kolor guzika
            
            if(wiersz%2==0 and guzik%2==0 or wiersz%2!=0 and guzik%2!=0):
                button_colour = color_white
            else:
                button_colour = color_dark
       
            #malujemy guzik
        
            pygame.draw.rect(screen,button_colour,buttons[buttons_count][guzik])
    
    
    

    
    
          # rysujemy pionki:
    class Pionek:
        def __init__(self):
            self.kolor_pionka
                
            
    #class Pionek_zwykly(Pionek):
            
            
    #class Damka(Pionek):
            
            
            
            
            
        #dla gracza pierwszego:
        
        
        
        
        
    for wiersz in range (1,9):  #ustawiamy pionki tylko w 3 rzedach
        
        if wiersz%2==0 :
            start=1
        else:
            start=0
            
        if(wiersz<4 or wiersz>5):
            for pionek in range (start, 8, 2):
                if(wiersz<4) :
                    tekst_wstawiany = text2
                else:
                    tekst_wstawiany = text1
                
                screen.blit(tekst_wstawiany , (100*pionek,100*wiersz)) # nakłada tekst na przycisk
                
                
                
                
    
        #podświetlamy guzik gdy na niego najedziemy:
        
    for wiersz in range (1,9):
        for guzik in range (0,8):
                
            if 100*guzik < mouse[0] < 100*guzik+100 and 100*wiersz < mouse[1] < 100*wiersz+100: 
                pygame.draw.rect(screen,color_light,[100*guzik,100*wiersz,100,100])
                
                        
        
  
                


                
    
    
    pygame.display.update()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-d703a3781a2f> in <module>
#      40
#      41
# ---> 42     mouse = pygame.mouse.get_pos()
#      43
#      44
#
# error: video system not initialized

# %%
#Dodawanie bibliotek
import pygame
import sys
import os
import kolory


import screen
import guzik
import szachownica
import gra



screen = screen.create_screen()    #tworzymy okno gry (okno, rozmiar_okna) zwraca to okno jako obiekt
gra = gra.Gra(screen)
gra.start()



#szachownica.create_szachownica(screen)  #tworymy szachownice zeskalowaną do rozmiaru okna gry
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(1), BUTTON([4][1])], [PIONEK(2), BUTTON([4][3])], [PIONEK(2), BUTTON([4][1])], [PIONEK(3), BUTTON([4][5])], [PIONEK(3), BUTTON([4][3])], [PIONEK(4), BUTTON([4][7])], [PIONEK(4), BUTTON([4][5])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(1), BUTTON([4][1])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(16), BUTTON([3][2])], [PIONEK(16), BUTTON([3][0])], [PIONEK(15), BUTTON([3][4])], [PIONEK(15), BUTTON([3][2])], [PIONEK(14), BUTTON([3][6])], [PIONEK(14), BUTTON([3][4])], [PIONEK(13), BUTTON([3][6])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(16), BUTTON([3][0])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(1), BUTTON([3][2])], [PIONEK(2), BUTTON([4][3])], [PIONEK(3), BUTTON([4][5])], [PIONEK(3), BUTTON([4][3])], [PIONEK(4), BUTTON([4][7])], [PIONEK(4), BUTTON([4][5])], [PIONEK(5), BUTTON([5][0])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(1), BUTTON([3][2])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(20), BUTTON([2][1])], [PIONEK(19), BUTTON([2][1])], [PIONEK(16), BUTTON([4][1])], [PIONEK(15), BUTTON([3][4])], [PIONEK(14), BUTTON([3][6])], [PIONEK(14), BUTTON([3][4])], [PIONEK(13), BUTTON([3][6])]]
# Moje ruchy z bicia:  [[PIONEK(15), BUTTON([4][1]), BUTTON([3][2])]]
# hej while
# Ruch:  [PIONEK(15), BUTTON([4][1])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(1), PIONEK(2), PIONEK(3), PIONEK(4), PIONEK(5), PIONEK(6), PIONEK(7), PIONEK(8), PIONEK(9), PIONEK(10), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 1,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(2), BUTTON([4][3])], [PIONEK(3), BUTTON([4][5])], [PIONEK(3), BUTTON([4][3])], [PIONEK(4), BUTTON([4][7])], [PIONEK(4), BUTTON([4][5])], [PIONEK(5), BUTTON([5][0])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(5), BUTTON([5][0])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(20), BUTTON([2][1])], [PIONEK(19), BUTTON([2][3])], [PIONEK(19), BUTTON([2][1])], [PIONEK(18), BUTTON([2][3])], [PIONEK(14), BUTTON([3][6])], [PIONEK(14), BUTTON([3][4])], [PIONEK(13), BUTTON([3][6])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(14), BUTTON([3][4])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(2), BUTTON([4][3])], [PIONEK(3), BUTTON([4][5])], [PIONEK(3), BUTTON([4][3])], [PIONEK(4), BUTTON([4][7])], [PIONEK(4), BUTTON([4][5])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][1])]]
# Moje ruchy z bicia:  [[PIONEK(5), BUTTON([3][2]), BUTTON([4][1])]]
# hej while
# Ruch:  [PIONEK(2), BUTTON([4][3])]
# Ruch nie dozwolony! sproboj jeszcze raz!
# masz prob:  2
# hej while
# Ruch:  [PIONEK(5), BUTTON([3][2])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(24), PIONEK(23), PIONEK(22), PIONEK(21), PIONEK(20), PIONEK(19), PIONEK(18), PIONEK(17), PIONEK(16), PIONEK(15), PIONEK(14), PIONEK(13)]
# obiekt pionek, id_pionka = 15,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(20), BUTTON([2][1])], [PIONEK(19), BUTTON([2][3])], [PIONEK(19), BUTTON([2][1])], [PIONEK(18), BUTTON([2][5])], [PIONEK(18), BUTTON([2][3])], [PIONEK(17), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])], [PIONEK(14), BUTTON([4][5])], [PIONEK(14), BUTTON([4][3])], [PIONEK(13), BUTTON([3][6])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(14), BUTTON([4][5])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(2), BUTTON([4][3])], [PIONEK(2), BUTTON([4][1])], [PIONEK(3), BUTTON([4][3])], [PIONEK(4), BUTTON([4][7])], [PIONEK(5), BUTTON([2][3])], [PIONEK(5), BUTTON([2][1])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][1])]]
# Moje ruchy z bicia:  [[PIONEK(3), BUTTON([3][6]), BUTTON([4][5])], [PIONEK(4), BUTTON([3][4]), BUTTON([4][5])]]
# hej while
# Ruch:  [PIONEK(4), BUTTON([3][4])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(24), PIONEK(23), PIONEK(22), PIONEK(21), PIONEK(20), PIONEK(19), PIONEK(18), PIONEK(17), PIONEK(16), PIONEK(14), PIONEK(13)]
# obiekt pionek, id_pionka = 14,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(20), BUTTON([2][1])], [PIONEK(19), BUTTON([2][3])], [PIONEK(19), BUTTON([2][1])], [PIONEK(18), BUTTON([2][5])], [PIONEK(18), BUTTON([2][3])], [PIONEK(17), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])], [PIONEK(13), BUTTON([3][6])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(18), BUTTON([2][3])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(2), BUTTON([4][3])], [PIONEK(2), BUTTON([4][1])], [PIONEK(3), BUTTON([4][5])], [PIONEK(3), BUTTON([4][3])], [PIONEK(4), BUTTON([2][5])], [PIONEK(5), BUTTON([2][1])], [PIONEK(7), BUTTON([5][6])], [PIONEK(8), BUTTON([5][6])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][1])]]
# Moje ruchy z bicia:  [[PIONEK(5), BUTTON([1][4]), BUTTON([2][3])]]
# hej while
# Ruch:  [PIONEK(5), BUTTON([1][4])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(24), PIONEK(23), PIONEK(22), PIONEK(21), PIONEK(20), PIONEK(19), PIONEK(18), PIONEK(17), PIONEK(16), PIONEK(13)]
# obiekt pionek, id_pionka = 18,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(20), BUTTON([2][1])], [PIONEK(19), BUTTON([2][3])], [PIONEK(19), BUTTON([2][1])], [PIONEK(17), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])], [PIONEK(13), BUTTON([3][6])]]
# Moje ruchy z bicia:  [[PIONEK(23), BUTTON([2][5]), BUTTON([1][4])], [PIONEK(22), BUTTON([2][3]), BUTTON([1][4])]]
# hej while
# Blad tu nie ma twojego pionka, to pionek twojego przeciwnika! sprobuj jeszcze raz!
# Blad tu nie ma twojego pionka, to pole jest puste sprobuj jeszcze raz!
# Ruch:  [PIONEK(16), BUTTON([4][1])]
# Ruch nie dozwolony! sproboj jeszcze raz!
# masz prob:  2
# hej while
# Ruch:  [PIONEK(22), BUTTON([2][3])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(2), PIONEK(3), PIONEK(4), PIONEK(5), PIONEK(6), PIONEK(7), PIONEK(8), PIONEK(9), PIONEK(10), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 5,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(2), BUTTON([4][3])], [PIONEK(2), BUTTON([4][1])], [PIONEK(3), BUTTON([4][5])], [PIONEK(3), BUTTON([4][3])], [PIONEK(4), BUTTON([2][5])], [PIONEK(7), BUTTON([5][6])], [PIONEK(8), BUTTON([5][6])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][1])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(8), BUTTON([5][6])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(23), BUTTON([1][4])], [PIONEK(22), BUTTON([3][2])], [PIONEK(20), BUTTON([2][1])], [PIONEK(19), BUTTON([2][1])], [PIONEK(17), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])], [PIONEK(13), BUTTON([3][6])]]
# Moje ruchy z bicia:  [[PIONEK(22), BUTTON([4][5]), BUTTON([3][4])]]
# hej while
# Ruch:  [PIONEK(22), BUTTON([4][5])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(2), PIONEK(3), PIONEK(4), PIONEK(6), PIONEK(7), PIONEK(8), PIONEK(9), PIONEK(10), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 4,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(2), BUTTON([4][3])], [PIONEK(2), BUTTON([4][1])], [PIONEK(3), BUTTON([4][3])], [PIONEK(8), BUTTON([4][7])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][1])], [PIONEK(12), BUTTON([6][7])]]
# Moje ruchy z bicia:  [[PIONEK(3), BUTTON([3][6]), BUTTON([4][5])], [PIONEK(8), BUTTON([3][4]), BUTTON([4][5])]]
# hej while
# Ruch:  [PIONEK(3), BUTTON([4][3])]
# Ruch nie dozwolony! sproboj jeszcze raz!
# masz prob:  2
# hej while
# Ruch:  [PIONEK(3), BUTTON([3][6])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(24), PIONEK(23), PIONEK(22), PIONEK(21), PIONEK(20), PIONEK(19), PIONEK(17), PIONEK(16), PIONEK(13)]
# obiekt pionek, id_pionka = 22,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(23), BUTTON([1][4])], [PIONEK(20), BUTTON([2][1])], [PIONEK(19), BUTTON([2][3])], [PIONEK(19), BUTTON([2][1])], [PIONEK(17), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])]]
# Moje ruchy z bicia:  [[PIONEK(13), BUTTON([4][5]), BUTTON([3][6])]]
# hej while
# Ruch:  [PIONEK(13), BUTTON([4][5])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(2), PIONEK(3), PIONEK(6), PIONEK(7), PIONEK(8), PIONEK(9), PIONEK(10), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 3,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(2), BUTTON([4][3])], [PIONEK(2), BUTTON([4][1])], [PIONEK(6), BUTTON([5][4])], [PIONEK(7), BUTTON([5][4])], [PIONEK(8), BUTTON([4][7])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][1])], [PIONEK(12), BUTTON([6][7])]]
# Moje ruchy z bicia:  [[PIONEK(8), BUTTON([3][4]), BUTTON([4][5])]]
# hej while
# Ruch:  [PIONEK(8), BUTTON([3][4])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(24), PIONEK(23), PIONEK(21), PIONEK(20), PIONEK(19), PIONEK(17), PIONEK(16), PIONEK(13)]
# obiekt pionek, id_pionka = 13,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(23), BUTTON([1][4])], [PIONEK(20), BUTTON([2][1])], [PIONEK(19), BUTTON([2][3])], [PIONEK(19), BUTTON([2][1])], [PIONEK(17), BUTTON([2][7])], [PIONEK(17), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(19), BUTTON([2][3])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(2), BUTTON([4][3])], [PIONEK(2), BUTTON([4][1])], [PIONEK(6), BUTTON([5][4])], [PIONEK(7), BUTTON([5][6])], [PIONEK(7), BUTTON([5][4])], [PIONEK(8), BUTTON([2][5])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][1])], [PIONEK(12), BUTTON([6][7])]]
# Moje ruchy z bicia:  [[PIONEK(8), BUTTON([1][2]), BUTTON([2][3])]]
# hej while
# Ruch:  [PIONEK(8), BUTTON([1][2])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(24), PIONEK(23), PIONEK(21), PIONEK(20), PIONEK(19), PIONEK(17), PIONEK(16)]
# obiekt pionek, id_pionka = 19,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(23), BUTTON([1][4])], [PIONEK(20), BUTTON([2][1])], [PIONEK(17), BUTTON([2][7])], [PIONEK(17), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])]]
# Moje ruchy z bicia:  [[PIONEK(24), BUTTON([2][3]), BUTTON([1][2])], [PIONEK(23), BUTTON([2][1]), BUTTON([1][2])]]
# hej while
# Ruch:  [PIONEK(23), BUTTON([2][1])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(2), PIONEK(6), PIONEK(7), PIONEK(8), PIONEK(9), PIONEK(10), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 8,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(2), BUTTON([4][3])], [PIONEK(2), BUTTON([4][1])], [PIONEK(6), BUTTON([5][4])], [PIONEK(7), BUTTON([5][6])], [PIONEK(7), BUTTON([5][4])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][1])], [PIONEK(12), BUTTON([6][7])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(2), BUTTON([4][3])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(24), BUTTON([1][2])], [PIONEK(23), BUTTON([3][2])], [PIONEK(17), BUTTON([2][7])], [PIONEK(17), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(23), BUTTON([3][2])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(2), BUTTON([3][4])], [PIONEK(6), BUTTON([5][4])], [PIONEK(6), BUTTON([5][2])], [PIONEK(7), BUTTON([5][6])], [PIONEK(7), BUTTON([5][4])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][1])], [PIONEK(12), BUTTON([6][7])]]
# Moje ruchy z bicia:  [[PIONEK(2), BUTTON([2][1]), BUTTON([3][2])]]
# hej while
# Ruch:  [PIONEK(2), BUTTON([2][1])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(24), PIONEK(23), PIONEK(21), PIONEK(20), PIONEK(17), PIONEK(16)]
# obiekt pionek, id_pionka = 23,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(24), BUTTON([1][2])], [PIONEK(17), BUTTON([2][7])], [PIONEK(17), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])]]
# Moje ruchy z bicia:  [[PIONEK(20), BUTTON([3][2]), BUTTON([2][1])]]
# hej while
# Ruch:  [PIONEK(20), BUTTON([3][2])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(2), PIONEK(6), PIONEK(7), PIONEK(9), PIONEK(10), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 2,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(6), BUTTON([5][4])], [PIONEK(6), BUTTON([5][2])], [PIONEK(7), BUTTON([5][6])], [PIONEK(7), BUTTON([5][4])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][1])], [PIONEK(12), BUTTON([6][7])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(6), BUTTON([5][2])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(24), BUTTON([1][2])], [PIONEK(24), BUTTON([1][0])], [PIONEK(20), BUTTON([4][3])], [PIONEK(20), BUTTON([4][1])], [PIONEK(17), BUTTON([2][7])], [PIONEK(17), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(20), BUTTON([4][1])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(6), BUTTON([4][3])], [PIONEK(7), BUTTON([5][6])], [PIONEK(7), BUTTON([5][4])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][3])], [PIONEK(10), BUTTON([6][1])], [PIONEK(11), BUTTON([6][3])], [PIONEK(12), BUTTON([6][7])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(7), BUTTON([5][4])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(24), BUTTON([1][2])], [PIONEK(24), BUTTON([1][0])], [PIONEK(20), BUTTON([5][0])], [PIONEK(17), BUTTON([2][7])], [PIONEK(17), BUTTON([2][5])]]
# Moje ruchy z bicia:  [[PIONEK(20), BUTTON([6][3]), BUTTON([5][2])]]
# hej while
# Ruch:  [PIONEK(20), BUTTON([6][3])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(6), PIONEK(7), PIONEK(9), PIONEK(10), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 6,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(7), BUTTON([4][5])], [PIONEK(7), BUTTON([4][3])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][1])], [PIONEK(11), BUTTON([6][5])], [PIONEK(12), BUTTON([6][7])], [PIONEK(12), BUTTON([6][5])]]
# Moje ruchy z bicia:  [[PIONEK(11), BUTTON([5][2]), BUTTON([6][3])]]
# hej while
# Ruch:  [PIONEK(11), BUTTON([5][2])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(24), PIONEK(21), PIONEK(20), PIONEK(17), PIONEK(16)]
# obiekt pionek, id_pionka = 20,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(24), BUTTON([1][2])], [PIONEK(24), BUTTON([1][0])], [PIONEK(17), BUTTON([2][7])], [PIONEK(17), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(24), BUTTON([1][2])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(7), BUTTON([4][5])], [PIONEK(7), BUTTON([4][3])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][3])], [PIONEK(10), BUTTON([6][1])], [PIONEK(11), BUTTON([4][3])], [PIONEK(11), BUTTON([4][1])], [PIONEK(12), BUTTON([6][7])], [PIONEK(12), BUTTON([6][5])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(7), BUTTON([4][3])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(24), BUTTON([2][3])], [PIONEK(24), BUTTON([2][1])], [PIONEK(17), BUTTON([2][7])], [PIONEK(17), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(17), BUTTON([2][5])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(7), BUTTON([3][4])], [PIONEK(7), BUTTON([3][2])], [PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][3])], [PIONEK(10), BUTTON([6][1])], [PIONEK(11), BUTTON([4][1])], [PIONEK(12), BUTTON([6][7])], [PIONEK(12), BUTTON([6][5])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(7), BUTTON([3][4])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(24), BUTTON([2][3])], [PIONEK(24), BUTTON([2][1])], [PIONEK(21), BUTTON([1][6])], [PIONEK(17), BUTTON([3][6])], [PIONEK(16), BUTTON([4][1])]]
# Moje ruchy z bicia:  [[PIONEK(17), BUTTON([4][3]), BUTTON([3][4])]]
# hej while
# Ruch:  [PIONEK(17), BUTTON([4][3])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(7), PIONEK(9), PIONEK(10), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 7,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][3])], [PIONEK(10), BUTTON([6][1])], [PIONEK(11), BUTTON([4][1])], [PIONEK(12), BUTTON([6][7])], [PIONEK(12), BUTTON([6][5])]]
# Moje ruchy z bicia:  [[PIONEK(11), BUTTON([3][4]), BUTTON([4][3])]]
# hej while
# Ruch:  [PIONEK(11), BUTTON([3][4])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(24), PIONEK(21), PIONEK(17), PIONEK(16)]
# obiekt pionek, id_pionka = 17,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(24), BUTTON([2][3])], [PIONEK(24), BUTTON([2][1])], [PIONEK(21), BUTTON([1][6])], [PIONEK(16), BUTTON([4][1])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(21), BUTTON([1][6])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][3])], [PIONEK(10), BUTTON([6][1])], [PIONEK(11), BUTTON([2][5])], [PIONEK(11), BUTTON([2][3])], [PIONEK(12), BUTTON([6][7])], [PIONEK(12), BUTTON([6][5])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(12), BUTTON([6][5])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(24), BUTTON([2][3])], [PIONEK(24), BUTTON([2][1])], [PIONEK(21), BUTTON([2][7])], [PIONEK(21), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(24), BUTTON([2][3])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][3])], [PIONEK(10), BUTTON([6][1])], [PIONEK(11), BUTTON([2][5])], [PIONEK(12), BUTTON([5][6])], [PIONEK(12), BUTTON([5][4])]]
# Moje ruchy z bicia:  [[PIONEK(11), BUTTON([1][2]), BUTTON([2][3])]]
# hej while
# Ruch:  [PIONEK(11), BUTTON([1][2])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(24), PIONEK(21), PIONEK(16)]
# obiekt pionek, id_pionka = 24,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(21), BUTTON([2][7])], [PIONEK(21), BUTTON([2][5])], [PIONEK(16), BUTTON([4][1])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(16), BUTTON([4][1])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([6][3])], [PIONEK(10), BUTTON([6][1])], [PIONEK(11), BUTTON([0][3])], [PIONEK(11), BUTTON([0][1])], [PIONEK(12), BUTTON([5][6])], [PIONEK(12), BUTTON([5][4])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(10), BUTTON([6][3])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(21), BUTTON([2][7])], [PIONEK(21), BUTTON([2][5])], [PIONEK(16), BUTTON([5][2])], [PIONEK(16), BUTTON([5][0])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(16), BUTTON([5][2])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([5][4])], [PIONEK(11), BUTTON([0][3])], [PIONEK(11), BUTTON([0][1])], [PIONEK(12), BUTTON([5][6])], [PIONEK(12), BUTTON([5][4])]]
# Moje ruchy z bicia:  [[PIONEK(10), BUTTON([4][1]), BUTTON([5][2])]]
# hej while
# Ruch:  [PIONEK(10), BUTTON([4][1])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(21), PIONEK(16)]
# obiekt pionek, id_pionka = 16,
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(21), BUTTON([2][7])], [PIONEK(21), BUTTON([2][5])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(21), BUTTON([2][5])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([3][2])], [PIONEK(10), BUTTON([3][0])], [PIONEK(11), BUTTON([0][3])], [PIONEK(11), BUTTON([0][1])], [PIONEK(12), BUTTON([5][6])], [PIONEK(12), BUTTON([5][4])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(11), BUTTON([0][1])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(21), BUTTON([3][6])], [PIONEK(21), BUTTON([3][4])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(21), BUTTON([3][4])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([3][2])], [PIONEK(10), BUTTON([3][0])], [PIONEK(11), BUTTON([7][2])], [PIONEK(12), BUTTON([5][6])], [PIONEK(12), BUTTON([5][4])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(10), BUTTON([3][0])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(21), BUTTON([4][5])], [PIONEK(21), BUTTON([4][3])]]
# Moje ruchy z bicia:  []
# hej while
# Blad tu nie ma twojego pionka, to pionek twojego przeciwnika! sprobuj jeszcze raz!
# Blad tu nie ma twojego pionka, to pole jest puste sprobuj jeszcze raz!
# Ruch:  [PIONEK(21), BUTTON([4][3])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([2][1])], [PIONEK(11), BUTTON([7][2])], [PIONEK(12), BUTTON([5][6])], [PIONEK(12), BUTTON([5][4])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(12), BUTTON([5][6])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(21), BUTTON([5][4])], [PIONEK(21), BUTTON([5][2])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(21), BUTTON([5][2])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([6][1])], [PIONEK(10), BUTTON([2][1])], [PIONEK(11), BUTTON([7][2])], [PIONEK(12), BUTTON([4][7])], [PIONEK(12), BUTTON([4][5])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(10), BUTTON([2][1])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(21), BUTTON([6][3])], [PIONEK(21), BUTTON([6][1])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(21), BUTTON([6][1])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(10), BUTTON([1][2])], [PIONEK(10), BUTTON([1][0])], [PIONEK(11), BUTTON([7][2])], [PIONEK(12), BUTTON([4][7])], [PIONEK(12), BUTTON([4][5])]]
# Moje ruchy z bicia:  [[PIONEK(9), BUTTON([5][2]), BUTTON([6][1])]]
# hej while
# Ruch:  [PIONEK(9), BUTTON([5][2])]
# wykonuje sie ruch
# ustawiam
# [PIONEK(21)]
# obiekt pionek, id_pionka = 21,
# Ruch gracza:
# Moje ruchy bez biciem:  []
# Moje ruchy z bicia:  []
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([4][3])], [PIONEK(9), BUTTON([4][1])], [PIONEK(10), BUTTON([1][2])], [PIONEK(10), BUTTON([1][0])], [PIONEK(11), BUTTON([7][2])], [PIONEK(11), BUTTON([7][0])], [PIONEK(12), BUTTON([4][7])], [PIONEK(12), BUTTON([4][5])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(12), BUTTON([4][5])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  []
# Moje ruchy z bicia:  []
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([4][3])], [PIONEK(9), BUTTON([4][1])], [PIONEK(10), BUTTON([1][2])], [PIONEK(10), BUTTON([1][0])], [PIONEK(11), BUTTON([7][2])], [PIONEK(11), BUTTON([7][0])], [PIONEK(12), BUTTON([3][6])], [PIONEK(12), BUTTON([3][4])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(9), BUTTON([4][3])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  []
# Moje ruchy z bicia:  []
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([3][4])], [PIONEK(9), BUTTON([3][2])], [PIONEK(10), BUTTON([1][2])], [PIONEK(10), BUTTON([1][0])], [PIONEK(11), BUTTON([7][2])], [PIONEK(11), BUTTON([7][0])], [PIONEK(12), BUTTON([3][6])], [PIONEK(12), BUTTON([3][4])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(9), BUTTON([3][4])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  []
# Moje ruchy z bicia:  []
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([2][5])], [PIONEK(9), BUTTON([2][3])], [PIONEK(10), BUTTON([1][2])], [PIONEK(10), BUTTON([1][0])], [PIONEK(11), BUTTON([7][2])], [PIONEK(11), BUTTON([7][0])], [PIONEK(12), BUTTON([3][6])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(10), BUTTON([1][2])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  []
# Moje ruchy z bicia:  []
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([2][5])], [PIONEK(9), BUTTON([2][3])], [PIONEK(10), BUTTON([0][3])], [PIONEK(11), BUTTON([7][2])], [PIONEK(11), BUTTON([7][0])], [PIONEK(12), BUTTON([3][6])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(10), BUTTON([0][3])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  []
# Moje ruchy z bicia:  []
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([2][5])], [PIONEK(9), BUTTON([2][3])], [PIONEK(10), BUTTON([7][4])], [PIONEK(10), BUTTON([7][2])], [PIONEK(11), BUTTON([7][2])], [PIONEK(11), BUTTON([7][0])], [PIONEK(12), BUTTON([3][6])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(9), BUTTON([2][5])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  []
# Moje ruchy z bicia:  []
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([1][6])], [PIONEK(9), BUTTON([1][4])], [PIONEK(10), BUTTON([7][4])], [PIONEK(10), BUTTON([7][2])], [PIONEK(11), BUTTON([7][2])], [PIONEK(11), BUTTON([7][0])], [PIONEK(12), BUTTON([3][6])], [PIONEK(12), BUTTON([3][4])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(9), BUTTON([1][4])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  []
# Moje ruchy z bicia:  []
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([0][5])], [PIONEK(10), BUTTON([7][4])], [PIONEK(10), BUTTON([7][2])], [PIONEK(11), BUTTON([7][2])], [PIONEK(11), BUTTON([7][0])], [PIONEK(12), BUTTON([3][6])], [PIONEK(12), BUTTON([3][4])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(9), BUTTON([0][5])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  []
# Moje ruchy z bicia:  []
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([7][6])], [PIONEK(9), BUTTON([7][4])], [PIONEK(10), BUTTON([7][4])], [PIONEK(10), BUTTON([7][2])], [PIONEK(11), BUTTON([7][2])], [PIONEK(11), BUTTON([7][0])], [PIONEK(12), BUTTON([3][6])], [PIONEK(12), BUTTON([3][4])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(12), BUTTON([3][6])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  []
# Moje ruchy z bicia:  []
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([7][6])], [PIONEK(9), BUTTON([7][4])], [PIONEK(10), BUTTON([7][4])], [PIONEK(10), BUTTON([7][2])], [PIONEK(11), BUTTON([7][2])], [PIONEK(11), BUTTON([7][0])], [PIONEK(12), BUTTON([2][7])], [PIONEK(12), BUTTON([2][5])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(12), BUTTON([2][5])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  []
# Moje ruchy z bicia:  []
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([7][6])], [PIONEK(9), BUTTON([7][4])], [PIONEK(10), BUTTON([7][4])], [PIONEK(10), BUTTON([7][2])], [PIONEK(11), BUTTON([7][2])], [PIONEK(11), BUTTON([7][0])], [PIONEK(12), BUTTON([1][6])], [PIONEK(12), BUTTON([1][4])]]
# Moje ruchy z bicia:  []
# hej while
# Blad tu nie ma twojego pionka, to pole jest puste sprobuj jeszcze raz!
# Ruch:  [PIONEK(12), BUTTON([1][6])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  []
# Moje ruchy z bicia:  []
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([7][6])], [PIONEK(9), BUTTON([7][4])], [PIONEK(10), BUTTON([7][4])], [PIONEK(10), BUTTON([7][2])], [PIONEK(11), BUTTON([7][2])], [PIONEK(11), BUTTON([7][0])], [PIONEK(12), BUTTON([0][7])]]
# Moje ruchy z bicia:  []
# hej while
# Ruch:  [PIONEK(12), BUTTON([0][7])]
# wykonuje sie ruch
# ustawiam
# Ruch gracza:
# Moje ruchy bez biciem:  []
# Moje ruchy z bicia:  []
# Ruch gracza:
# Moje ruchy bez biciem:  [[PIONEK(9), BUTTON([7][6])], [PIONEK(9), BUTTON([7][4])], [PIONEK(10), BUTTON([7][4])], [PIONEK(10), BUTTON([7][2])], [PIONEK(11), BUTTON([7][2])], [PIONEK(11), BUTTON([7][0])], [PIONEK(12), BUTTON([7][6])]]
# Moje ruchy z bicia:  []
# hej while
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-f362ccac469b> in <module>
#      15 screen = screen.create_screen()    #tworzymy okno gry (okno, rozmiar_okna) zwraca to okno jako obiekt
#      16 gra = gra.Gra(screen)
# ---> 17 gra.start()
#      18
#      19
#
# ~\Gra-Warcaby\gra.py in start(self)
#     115                     print("Ruch gracza:  ")
#     116                     ruch = Ruch(gracz_aktualny, self.szachownica.get_net_buttons(), self, przeciwnik)  #aktualna siatka guzikow  self to gra
# --> 117                     status = ruch.pobierz_ruch_uzytkownika()
#     118
#     119
#
# ~\Gra-Warcaby\ruch.py in pobierz_ruch_uzytkownika(self)
#      56             print("hej while")
#      57
# ---> 58             self.skad = self.wybierz_swoj_pionek()
#      59             if(self.skad) == False:     #nie udalo sie pobrac, minął czas
#      60                 return True #gra idzie dalej
#
# ~\Gra-Warcaby\ruch.py in wybierz_swoj_pionek(self)
#     149                     klik=True
#     150
# --> 151             mouse = pygame.mouse.get_pos()
#     152
#     153             for wiersz_guzikow in self.net_buttons:
#
# error: video system not initialized
