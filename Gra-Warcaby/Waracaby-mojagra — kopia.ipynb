# %%
import pygame

# %%
pygame.init()  
scr = pygame.display.set_mode((600,500))  
pygame.display.set_caption('Gra - Warcaby')
done = False  
while not done:  
    for event in pygame.event.get():  
        if event.type == pygame.QUIT:  
            done = True  
pygame.display.flip()

# %%
import pygame
pygame.init() 
scr = pygame.display.set_mode((600,500))
print(scr)
x, y = scr.get_size() 
pygame.display.quit() 
print(x, y)

# %%
import pygame 
import sys  
import os

pygame.init()

X = 500
Y = 550
os.environ['SDL_VIDEO_WINDOW_POS'] = "%d,%d" % (X,Y)

s = (800, 1000)

screen = pygame.display.set_mode(s)

# przechowujemy kolory
color_white = (255,255,255) 
color_light = (180,180,180) 
color_dark = (110,110,110) 

#wysokosc i szerokosc ekranu
width = screen.get_width()
height = screen.get_height()  

#definicja czcionki i rozmiar
smallfont = pygame.font.SysFont('Arial',80) 
text1 = smallfont.render('B' , True , color_white) 
text2 = smallfont.render('C' , True , color_white) 


while True:     
    for e in pygame.event.get():      
        if e.type == pygame.QUIT: 
            pygame.quit()      
        if e.type == pygame.MOUSEBUTTONDOWN:  #sprawdza czy mysz jest klikana
            # jesli mysz klikana sprawdzamy cyz jest kliknana na guzik
            if width/2 <= mouse[0] <= width/2+140 and height/2 <= mouse[1] <= height/2+40: 
                pygame.quit() 
                
    #screen.fill((0,0,0)) #wypelnia ekran czarnym kolorem
    
    
    mouse = pygame.mouse.get_pos() 
    
    
    
    #SZACHOWNICA PLANSZA
    
    
    liczba_wierszy = 8
    liczba_kolumn = 8
    buttons = []
    
    for i in range(liczba_wierszy):
        buttons.append([0] * liczba_kolumn)

        
        
    #malujemy 64 guzików: plasza 8x8
    buttons_count = -1
    
    for wiersz in range (1,9):
        buttons_count += 1
        for guzik in range (0,8):
            buttons[buttons_count][guzik]=[100*guzik, 100*wiersz, 100, 100]
            
            #ustawiamy kolor guzika
            
            if(wiersz%2==0 and guzik%2==0 or wiersz%2!=0 and guzik%2!=0):
                button_colour = color_white
            else:
                button_colour = color_dark
       
            #malujemy guzik
        
            pygame.draw.rect(screen,button_colour,buttons[buttons_count][guzik])
    
    
    

    
    
          # rysujemy pionki:
    class Pionek:
        def __init__(self):
            self.kolor_pionka
                
            
    #class Pionek_zwykly(Pionek):
            
            
    #class Damka(Pionek):
            
            
            
            
            
        #dla gracza pierwszego:
        
        
        
        
        
    for wiersz in range (1,9):  #ustawiamy pionki tylko w 3 rzedach
        
        if wiersz%2==0 :
            start=1
        else:
            start=0
            
        if(wiersz<4 or wiersz>5):
            for pionek in range (start, 8, 2):
                if(wiersz<4) :
                    tekst_wstawiany = text2
                else:
                    tekst_wstawiany = text1
                
                screen.blit(tekst_wstawiany , (100*pionek,100*wiersz)) # nakłada tekst na przycisk
                
                
                
                
    
        #podświetlamy guzik gdy na niego najedziemy:
        
    for wiersz in range (1,9):
        for guzik in range (0,8):
                
            if 100*guzik < mouse[0] < 100*guzik+100 and 100*wiersz < mouse[1] < 100*wiersz+100: 
                pygame.draw.rect(screen,color_light,[100*guzik,100*wiersz,100,100])
                
                        
        
  
                


                
    
    
    pygame.display.update()
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
#Dodawanie bibliotek
import pygame
import sys
import os
import kolory


import screen
import guzik
import szachownica
import gra



screen = screen.create_screen()    #tworzymy okno gry (okno, rozmiar_okna) zwraca to okno jako obiekt
gra = gra.Gra(screen)
gra.start()



#szachownica.create_szachownica(screen)  #tworymy szachownice zeskalowaną do rozmiaru okna gry
# Out:
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# [PIONEK(1), PIONEK(2), PIONEK(3), PIONEK(4), PIONEK(5), PIONEK(6), PIONEK(7), PIONEK(8), PIONEK(9), PIONEK(10), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 2,
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# [PIONEK(24), PIONEK(23), PIONEK(22), PIONEK(21), PIONEK(20), PIONEK(19), PIONEK(18), PIONEK(17), PIONEK(16), PIONEK(15), PIONEK(14), PIONEK(13)]
# obiekt pionek, id_pionka = 16,
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# [PIONEK(1), PIONEK(3), PIONEK(4), PIONEK(5), PIONEK(6), PIONEK(7), PIONEK(8), PIONEK(9), PIONEK(10), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 3,
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# [PIONEK(1), PIONEK(4), PIONEK(5), PIONEK(6), PIONEK(7), PIONEK(8), PIONEK(9), PIONEK(10), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 1,
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# 1200 900
# 1200 900
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# 1200 900
# 1200 900
# 1200 900
# 1200 900
# 1200 900
# 1200 900
# 1200 900
# 1200 900
# ustawiam
# [PIONEK(24), PIONEK(23), PIONEK(22), PIONEK(21), PIONEK(20), PIONEK(19), PIONEK(18), PIONEK(17), PIONEK(15), PIONEK(14), PIONEK(13)]
# obiekt pionek, id_pionka = 15,
# 1200 900
# 1200 900
# 1200 900
# ustawiam
# [PIONEK(24), PIONEK(23), PIONEK(22), PIONEK(21), PIONEK(20), PIONEK(19), PIONEK(18), PIONEK(17), PIONEK(14), PIONEK(13)]
# obiekt pionek, id_pionka = 19,
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# [PIONEK(4), PIONEK(5), PIONEK(6), PIONEK(7), PIONEK(8), PIONEK(9), PIONEK(10), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 5,
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# ustawiam
# [PIONEK(4), PIONEK(6), PIONEK(7), PIONEK(8), PIONEK(9), PIONEK(10), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 10,
# ustawiam
# 1200 900
# ustawiam
# [PIONEK(4), PIONEK(6), PIONEK(7), PIONEK(8), PIONEK(9), PIONEK(11), PIONEK(12)]
# obiekt pionek, id_pionka = 6,
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# [PIONEK(24), PIONEK(23), PIONEK(22), PIONEK(21), PIONEK(18), PIONEK(17), PIONEK(14), PIONEK(13), DAMKA(20)]
# obiekt damka, id_pionka = 20,
# 1200 900
# ustawiam
# [PIONEK(24), PIONEK(23), PIONEK(22), PIONEK(21), PIONEK(18), PIONEK(17), PIONEK(14), PIONEK(13)]
# obiekt pionek, id_pionka = 23,
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# [PIONEK(24), PIONEK(22), PIONEK(21), PIONEK(18), PIONEK(17), PIONEK(14), PIONEK(13)]
# obiekt pionek, id_pionka = 24,
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# 1200 900
# 1200 900
# 1200 900
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# 1200 900
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# [PIONEK(22), PIONEK(21), PIONEK(18), PIONEK(17), PIONEK(14), PIONEK(13)]
# obiekt pionek, id_pionka = 18,
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# 1200 900
# 1200 900
# 1200 900
# 1200 900
# ustawiam
# [PIONEK(4), PIONEK(8), PIONEK(9), PIONEK(11), PIONEK(12), DAMKA(7)]
# obiekt pionek, id_pionka = 4,
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# [PIONEK(22), PIONEK(21), PIONEK(17), PIONEK(14), PIONEK(13)]
# obiekt pionek, id_pionka = 14,
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# [PIONEK(22), PIONEK(21), PIONEK(17), PIONEK(13)]
# obiekt pionek, id_pionka = 17,
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# [PIONEK(22), PIONEK(21), PIONEK(13)]
# obiekt pionek, id_pionka = 22,
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# 1200 900
# 1200 900
# 1200 900
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# 1200 900
# 1200 900
# 1200 900
# 1200 900
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# ustawiam
# [PIONEK(21), PIONEK(13)]
# obiekt pionek, id_pionka = 21,
# 1200 900
# 1200 900
# ustawiam
# [PIONEK(13)]
# obiekt pionek, id_pionka = 13,
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# Ruch gracza:
# ustawiam
# 1200 900
# 1200 900
# Ruch gracza:
# 1200 900
# Ruch gracza:
# 1200 900
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-f362ccac469b> in <module>
#      15 screen = screen.create_screen()    #tworzymy okno gry (okno, rozmiar_okna) zwraca to okno jako obiekt
#      16 gra = gra.Gra(screen)
# ---> 17 gra.start()
#      18
#      19
#
# ~\Gra-Warcaby\gra.py in start(self)
#     186                     print("Ruch gracza:  ")
#     187                     ruch = Ruch(gracz_aktualny, self.szachownica.get_net_buttons(), self, przeciwnik)  #aktualna siatka guzikow  self to gra
# --> 188                     status = ruch.pobierz_ruch_uzytkownika()
#     189
#     190
#
# ~\Gra-Warcaby\ruch.py in pobierz_ruch_uzytkownika(self)
#      64                 return True #gra idzie dalej
#      65
# ---> 66             self.dokad= self.wybierz_pole(self.skad) #tutaj nie mozemy gasic guzika wybranego w skad!
#      67             if(self.dokad) == False:     #nie udalo sie pobrac minal czas
#      68                 return True
#
# ~\Gra-Warcaby\ruch.py in wybierz_pole(self, wylaczony_guzik)
#     269                     klik=True
#     270
# --> 271             mouse = pygame.mouse.get_pos()
#     272
#     273             for wiersz_guzikow in self.net_buttons:
#
# error: video system not initialized
